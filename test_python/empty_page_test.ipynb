# %%
from platform_utils import print_info

print_info()
# Out:
# macOS-14.2.1-arm64-arm-64bit
# ======================================== System Information ========================================
# System: Darwin
# Release: 23.2.0
# Version: Darwin Kernel Version 23.2.0: Wed Nov 15 21:54:51 PST 2023; root:xnu-10002.61.3~2/RELEASE_ARM64_T6030
# Machine: arm64
# Processor: arm
# ======================================== CPU Info ========================================
# Physical cores: 12
# Total cores: 12
# Max Frequency: 4056.00Mhz
# Min Frequency: 696.00Mhz
# Current Frequency: 4056.00Mhz
# ======================================== Memory Information ========================================
# Total: 18.00GB
# Available: 9.99GB
# Used: 7.20GB
# Percentage: 44.5%
# ==================== SWAP ====================
# Total: 0.00B
# Free: 0.00B
# Used: 0.00B
# Percentage: 0.0%

# %%
# %pip install matplotlib
# %pip install numpy
# %pip install selenium
# %pip install psrecord
# %pip install pandas
# Out:
# Requirement already satisfied: matplotlib in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: selenium in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (4.19.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.1)
# Requirement already satisfied: trio~=0.17 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: psrecord in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (1.2)
# Requirement already satisfied: psutil>=2 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from psrecord) (5.9.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/szkania/studies/geant4-wasm-performance/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# run web server in separate thread

import subprocess
import os

server_cmd = "python3 -m http.server 5500"

server = subprocess.Popen(server_cmd.split(), cwd=os.getcwd())

# %%
import time


# create results directory
os.makedirs('./empty_page/output', exist_ok=True)
    
    
from selenium_utils import create_firefox_driver, create_chromium_driver
    
    
def execute_test(driver, name):
    log_name = name.lower()
    subprocess.Popen(
        f"psrecord {driver.service.process.pid} --log ./empty_page/output/{log_name}.usage.log --include-children".split(
            " "
        )
    )

    driver.set_script_timeout(30)
    driver.get("http://127.0.0.1:5500/empty_page/empty.html")
    
    # wait 10s 
    time.sleep(10)

    driver.close()
    

execute_test(create_firefox_driver(), "firefox")

execute_test(create_chromium_driver(), "chromium")
# Out:
# ::ffff:127.0.0.1 - - [19/Apr/2024 20:54:29] "GET /empty_page/empty.html HTTP/1.1" 200 -
# ::ffff:127.0.0.1 - - [19/Apr/2024 20:54:29] code 404, message File not found
# ::ffff:127.0.0.1 - - [19/Apr/2024 20:54:29] "GET /favicon.ico HTTP/1.1" 404 -
# Attaching to process 1703
# ::ffff:127.0.0.1 - - [19/Apr/2024 20:54:44] "GET /empty_page/empty.html HTTP/1.1" 200 -
# Attaching to process 1755
# Process finished (10.07 seconds)

# %%
server.kill()
