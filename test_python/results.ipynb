# %%
import platform 
print(platform.platform())
# Out:
# macOS-14.2.1-arm64-arm-64bit

# %%
# Prepare env for running the tests
# Paths are relative to the root of the repository

# `./hostExample.sh` to start the webserver

# to generate env file run `source ./geant4/native-multithread/geant4.10.04.p03/install/bin/geant4.sh && printenv > ./test-python/.env`
# %pip install python-dotenv
# %pip install matplotlib
# %pip install numpy
# %pip install selenium
# %pip install psrecord
# %pip install pandas
# Out:
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.12/site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: selenium in ./.venv/lib/python3.12/site-packages (4.18.1)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.1)
# Requirement already satisfied: trio~=0.17 in ./.venv/lib/python3.12/site-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in ./.venv/lib/python3.12/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in ./.venv/lib/python3.12/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in ./.venv/lib/python3.12/site-packages (from selenium) (4.10.0)
# Requirement already satisfied: attrs>=23.2.0 in ./.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in ./.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in ./.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in ./.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in ./.venv/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in ./.venv/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in ./.venv/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in ./.venv/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: psrecord in ./.venv/lib/python3.12/site-packages (1.2)
# Requirement already satisfied: psutil>=2 in ./.venv/lib/python3.12/site-packages (from psrecord) (5.9.8)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-2.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 37.2 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.1 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import dotenv_values

env_values = dotenv_values()

# %%
import subprocess
import os

n_threads = [1, 2, 3, 4, 6, 8, 10, 12]
# n_threads = [8]

# create results directory
os.makedirs('./results', exist_ok=True)


for n_thread in n_threads:
    print(f'Running test with {n_thread} threads')
    subprocess.call(f'python3 test.py --n_threads {n_thread}', shell=True,env=env_values)
    
    folder_output_name = f'./results/thread_{n_thread}'
    
    os.makedirs(folder_output_name, exist_ok=True)
    
    # copy the output files to the results directory
    subprocess.call(f'cp ./output/* {folder_output_name}', shell=True)
# Out:
# Running test with 1 threads
# Attaching to process 11186
# Attaching to process 11511
# Process finished (53.93 seconds)
# Process not running firefox
# Running firefox test
# Firefox [47]
# 48241
# Firefox [{'clear': 2, 'end': 1711115549139, 'init': 427, 'preClear': 1711115549137, 'preInit': 1711115501462, 'preRun': 1711115501889, 'run': 47248}]
# Firefox 559
# Finished firefox test 49896 ms
# Process not running chrome
# Running chromium test
# Chromium [53]
# 53734.59999999986
# Chromium [{'clear': 2, 'end': 1711115604208, 'init': 231, 'preClear': 1711115604206, 'preInit': 1711115550790, 'preRun': 1711115551021, 'run': 53185}]
# Chromium 311.5
# Finished chromium test 54772 ms
# Process not running exampleB1
# Running native test
# native run,38
#
# Finished native test 39541 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,40
#
# Finished native-multithread test 41772 ms
# Running test with 2 threads
# Attaching to process 12338
# Attaching to process 12555
# Process finished (27.92 seconds)
# Process not running firefox
# Running firefox test
# Firefox [26, 24]
# 27639
# Firefox [{'clear': 1, 'end': 1711115714611, 'init': 514, 'preClear': 1711115714610, 'preInit': 1711115687837, 'preRun': 1711115688351, 'run': 26259}, {'clear': 1, 'end': 1711115713135, 'init': 447, 'preClear': 1711115713134, 'preInit': 1711115687836, 'preRun': 1711115688283, 'run': 24851}]
# Firefox 858
# Finished firefox test 29222 ms
# Process not running chrome
# Running chromium test
# Chromium [27, 27]
# 27717.59999999986
# Chromium [{'clear': 1, 'end': 1711115743430, 'init': 245, 'preClear': 1711115743429, 'preInit': 1711115716106, 'preRun': 1711115716351, 'run': 27078}, {'clear': 2, 'end': 1711115743380, 'init': 246, 'preClear': 1711115743378, 'preInit': 1711115716105, 'preRun': 1711115716351, 'run': 27027}]
# Chromium 386.39999999990687
# Finished chromium test 28521 ms
# Process not running exampleB1
# Running native test
# native run,37
#
# Finished native test 39248 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,19
#
# Finished native-multithread test 21498 ms
# Running test with 3 threads
# Attaching to process 13147
# Attaching to process 13366
# Process not running firefox
# Running firefox test
# Firefox [22, 25, 24]
# 27593
# Firefox [{'clear': 3, 'end': 1711115830843, 'init': 488, 'preClear': 1711115830840, 'preInit': 1711115807480, 'preRun': 1711115807968, 'run': 22872}, {'clear': 2, 'end': 1711115833298, 'init': 534, 'preClear': 1711115833296, 'preInit': 1711115807482, 'preRun': 1711115808016, 'run': 25280}, {'clear': 2, 'end': 1711115832351, 'init': 529, 'preClear': 1711115832349, 'preInit': 1711115807480, 'preRun': 1711115808009, 'run': 24340}]
# Firefox 1766
# Finished firefox test 29266 ms
# Process not running chrome
# Running chromium test
# Chromium [18, 18, 18]
# 19399.5
# Chromium [{'clear': 3, 'end': 1711115853716, 'init': 257, 'preClear': 1711115853713, 'preInit': 1711115834934, 'preRun': 1711115835191, 'run': 18522}, {'clear': 2, 'end': 1711115853716, 'init': 257, 'preClear': 1711115853714, 'preInit': 1711115834934, 'preRun': 1711115835191, 'run': 18523}, {'clear': 1, 'end': 1711115853803, 'init': 257, 'preClear': 1711115853802, 'preInit': 1711115834934, 'preRun': 1711115835191, 'run': 18611}]
# Chromium 515.1000000000931
# Finished chromium test 20204 ms
# Process not running exampleB1
# Running native test
# native run,37
#
# Finished native test 39224 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,13
#
# Finished native-multithread test 15387 ms
# Running test with 4 threads
# Attaching to process 13870
# Attaching to process 14058
# Process not running firefox
# Running firefox test
# Firefox [19, 16, 17, 18]
# 22139
# Firefox [{'clear': 2, 'end': 1711115932041, 'init': 475, 'preClear': 1711115932039, 'preInit': 1711115911767, 'preRun': 1711115912242, 'run': 19797}, {'clear': 3, 'end': 1711115928358, 'init': 480, 'preClear': 1711115928355, 'preInit': 1711115911767, 'preRun': 1711115912247, 'run': 16108}, {'clear': 3, 'end': 1711115929409, 'init': 533, 'preClear': 1711115929406, 'preInit': 1711115911768, 'preRun': 1711115912301, 'run': 17105}, {'clear': 2, 'end': 1711115930970, 'init': 540, 'preClear': 1711115930968, 'preInit': 1711115911768, 'preRun': 1711115912308, 'run': 18660}]
# Firefox 1855
# Finished firefox test 23733 ms
# Process not running chrome
# Running chromium test
# Chromium [14, 14, 14, 14]
# 15309.600000000093
# Chromium [{'clear': 2, 'end': 1711115948139, 'init': 267, 'preClear': 1711115948137, 'preInit': 1711115933397, 'preRun': 1711115933664, 'run': 14473}, {'clear': 3, 'end': 1711115948119, 'init': 267, 'preClear': 1711115948116, 'preInit': 1711115933397, 'preRun': 1711115933664, 'run': 14452}, {'clear': 2, 'end': 1711115948124, 'init': 266, 'preClear': 1711115948122, 'preInit': 1711115933398, 'preRun': 1711115933664, 'run': 14458}, {'clear': 1, 'end': 1711115948145, 'init': 267, 'preClear': 1711115948144, 'preInit': 1711115933397, 'preRun': 1711115933664, 'run': 14480}]
# Chromium 555.7999999998137
# Finished chromium test 15805 ms
# Process not running exampleB1
# Running native test
# native run,37
#
# Finished native test 39431 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,11
#
# Finished native-multithread test 12540 ms
# Running test with 6 threads
# Attaching to process 14529
# Attaching to process 14726
# Process not running firefox
# Running firefox test
# Firefox [18, 21, 19, 16, 13, 15]
# 24162
# Firefox [{'clear': 3, 'end': 1711116022770, 'init': 577, 'preClear': 1711116022767, 'preInit': 1711116003810, 'preRun': 1711116004387, 'run': 18380}, {'clear': 2, 'end': 1711116025760, 'init': 623, 'preClear': 1711116025758, 'preInit': 1711116003810, 'preRun': 1711116004433, 'run': 21325}, {'clear': 1, 'end': 1711116024114, 'init': 603, 'preClear': 1711116024113, 'preInit': 1711116003811, 'preRun': 1711116004414, 'run': 19699}, {'clear': 3, 'end': 1711116021264, 'init': 589, 'preClear': 1711116021261, 'preInit': 1711116003813, 'preRun': 1711116004402, 'run': 16859}, {'clear': 2, 'end': 1711116018289, 'init': 573, 'preClear': 1711116018287, 'preInit': 1711116003813, 'preRun': 1711116004386, 'run': 13901}, {'clear': 3, 'end': 1711116020030, 'init': 547, 'preClear': 1711116020027, 'preInit': 1711116003810, 'preRun': 1711116004357, 'run': 15670}]
# Firefox 2185
# Finished firefox test 25782 ms
# Process not running chrome
# Running chromium test
# Chromium [10, 10, 10, 10, 10, 10]
# 12020.799999999814
# Chromium [{'clear': 1, 'end': 1711116038488, 'init': 306, 'preClear': 1711116038487, 'preInit': 1711116027324, 'preRun': 1711116027630, 'run': 10857}, {'clear': 1, 'end': 1711116038589, 'init': 307, 'preClear': 1711116038588, 'preInit': 1711116027323, 'preRun': 1711116027630, 'run': 10958}, {'clear': 1, 'end': 1711116038556, 'init': 307, 'preClear': 1711116038555, 'preInit': 1711116027323, 'preRun': 1711116027630, 'run': 10925}, {'clear': 3, 'end': 1711116038253, 'init': 308, 'preClear': 1711116038250, 'preInit': 1711116027322, 'preRun': 1711116027630, 'run': 10620}, {'clear': 1, 'end': 1711116038517, 'init': 308, 'preClear': 1711116038516, 'preInit': 1711116027322, 'preRun': 1711116027630, 'run': 10886}, {'clear': 1, 'end': 1711116038298, 'init': 307, 'preClear': 1711116038297, 'preInit': 1711116027323, 'preRun': 1711116027630, 'run': 10667}]
# Chromium 748.2000000001863
# Finished chromium test 12532 ms
# Process not running exampleB1
# Running native test
# native run,38
#
# Finished native test 39549 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,8
#
# Finished native-multithread test 10250 ms
# Running test with 8 threads
# Attaching to process 15141
# Attaching to process 15337
# Process not running firefox
# Running firefox test
# Firefox [18, 12, 20, 16, 14, 19, 20, 20]
# 23183
# Firefox [{'clear': 1, 'end': 1711116110684, 'init': 577, 'preClear': 1711116110683, 'preInit': 1711116091985, 'preRun': 1711116092562, 'run': 18121}, {'clear': 3, 'end': 1711116105286, 'init': 563, 'preClear': 1711116105283, 'preInit': 1711116091982, 'preRun': 1711116092545, 'run': 12738}, {'clear': 2, 'end': 1711116112882, 'init': 597, 'preClear': 1711116112880, 'preInit': 1711116091981, 'preRun': 1711116092578, 'run': 20302}, {'clear': 3, 'end': 1711116108997, 'init': 736, 'preClear': 1711116108994, 'preInit': 1711116091982, 'preRun': 1711116092718, 'run': 16276}, {'clear': 2, 'end': 1711116107212, 'init': 664, 'preClear': 1711116107210, 'preInit': 1711116091983, 'preRun': 1711116092647, 'run': 14563}, {'clear': 2, 'end': 1711116112376, 'init': 605, 'preClear': 1711116112374, 'preInit': 1711116091984, 'preRun': 1711116092589, 'run': 19785}, {'clear': 4, 'end': 1711116112899, 'init': 685, 'preClear': 1711116112895, 'preInit': 1711116091985, 'preRun': 1711116092670, 'run': 20225}, {'clear': 1, 'end': 1711116113079, 'init': 712, 'preClear': 1711116113078, 'preInit': 1711116091985, 'preRun': 1711116092697, 'run': 20381}]
# Firefox 2072
# Finished firefox test 24847 ms
# Process not running chrome
# Running chromium test
# Chromium [10, 10, 10, 10, 10, 10, 10, 10]
# 11969.200000000186
# Chromium [{'clear': 5, 'end': 1711116125523, 'init': 378, 'preClear': 1711116125518, 'preInit': 1711116114919, 'preRun': 1711116115297, 'run': 10221}, {'clear': 1, 'end': 1711116125873, 'init': 388, 'preClear': 1711116125872, 'preInit': 1711116114919, 'preRun': 1711116115307, 'run': 10565}, {'clear': 1, 'end': 1711116125640, 'init': 302, 'preClear': 1711116125639, 'preInit': 1711116115018, 'preRun': 1711116115320, 'run': 10319}, {'clear': 1, 'end': 1711116125723, 'init': 401, 'preClear': 1711116125722, 'preInit': 1711116114921, 'preRun': 1711116115322, 'run': 10400}, {'clear': 1, 'end': 1711116125727, 'init': 378, 'preClear': 1711116125726, 'preInit': 1711116114920, 'preRun': 1711116115298, 'run': 10428}, {'clear': 1, 'end': 1711116125722, 'init': 373, 'preClear': 1711116125721, 'preInit': 1711116114921, 'preRun': 1711116115294, 'run': 10427}, {'clear': 1, 'end': 1711116125612, 'init': 377, 'preClear': 1711116125611, 'preInit': 1711116114920, 'preRun': 1711116115297, 'run': 10314}, {'clear': 2, 'end': 1711116125687, 'init': 382, 'preClear': 1711116125685, 'preInit': 1711116114921, 'preRun': 1711116115303, 'run': 10382}]
# Chromium 1009
# Finished chromium test 12491 ms
# Process not running exampleB1
# Running native test
# native run,37
#
# Finished native test 39354 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,7
#
# Finished native-multithread test 8950 ms
# Running test with 10 threads
# Attaching to process 15772
# Attaching to process 15968
# Process not running firefox
# Running firefox test
# Firefox [18, 19, 18, 19, 19, 13, 16, 11, 15, 19]
# 23312
# Firefox [{'clear': 2, 'end': 1711116198667, 'init': 700, 'preClear': 1711116198665, 'preInit': 1711116179014, 'preRun': 1711116179714, 'run': 18951}, {'clear': 2, 'end': 1711116198769, 'init': 722, 'preClear': 1711116198767, 'preInit': 1711116179017, 'preRun': 1711116179739, 'run': 19028}, {'clear': 4, 'end': 1711116198705, 'init': 812, 'preClear': 1711116198701, 'preInit': 1711116179015, 'preRun': 1711116179827, 'run': 18874}, {'clear': 2, 'end': 1711116198937, 'init': 807, 'preClear': 1711116198935, 'preInit': 1711116179018, 'preRun': 1711116179825, 'run': 19110}, {'clear': 2, 'end': 1711116198880, 'init': 789, 'preClear': 1711116198878, 'preInit': 1711116179013, 'preRun': 1711116179802, 'run': 19076}, {'clear': 2, 'end': 1711116193146, 'init': 822, 'preClear': 1711116193144, 'preInit': 1711116179015, 'preRun': 1711116179837, 'run': 13307}, {'clear': 49, 'end': 1711116196839, 'init': 782, 'preClear': 1711116196790, 'preInit': 1711116179015, 'preRun': 1711116179797, 'run': 16993}, {'clear': 6, 'end': 1711116190985, 'init': 802, 'preClear': 1711116190979, 'preInit': 1711116179017, 'preRun': 1711116179819, 'run': 11160}, {'clear': 3, 'end': 1711116195113, 'init': 853, 'preClear': 1711116195110, 'preInit': 1711116179021, 'preRun': 1711116179874, 'run': 15236}, {'clear': 5, 'end': 1711116198760, 'init': 714, 'preClear': 1711116198755, 'preInit': 1711116179015, 'preRun': 1711116179729, 'run': 19026}]
# Firefox 3378
# Finished firefox test 24905 ms
# Process not running chrome
# Running chromium test
# Chromium [9, 9, 7, 9, 9, 9, 9, 7, 9, 9]
# 10796.399999999907
# Chromium [{'clear': 1, 'end': 1711116210661, 'init': 329, 'preClear': 1711116210660, 'preInit': 1711116201273, 'preRun': 1711116201602, 'run': 9058}, {'clear': 1, 'end': 1711116210707, 'init': 408, 'preClear': 1711116210706, 'preInit': 1711116201173, 'preRun': 1711116201581, 'run': 9125}, {'clear': 2, 'end': 1711116209415, 'init': 368, 'preClear': 1711116209413, 'preInit': 1711116201173, 'preRun': 1711116201541, 'run': 7872}, {'clear': 2, 'end': 1711116210666, 'init': 408, 'preClear': 1711116210664, 'preInit': 1711116201172, 'preRun': 1711116201580, 'run': 9084}, {'clear': 2, 'end': 1711116210641, 'init': 413, 'preClear': 1711116210639, 'preInit': 1711116201173, 'preRun': 1711116201586, 'run': 9053}, {'clear': 1, 'end': 1711116210706, 'init': 414, 'preClear': 1711116210705, 'preInit': 1711116201174, 'preRun': 1711116201588, 'run': 9117}, {'clear': 3, 'end': 1711116210605, 'init': 410, 'preClear': 1711116210602, 'preInit': 1711116201172, 'preRun': 1711116201582, 'run': 9020}, {'clear': 3, 'end': 1711116209391, 'init': 377, 'preClear': 1711116209388, 'preInit': 1711116201175, 'preRun': 1711116201552, 'run': 7836}, {'clear': 2, 'end': 1711116210699, 'init': 339, 'preClear': 1711116210697, 'preInit': 1711116201274, 'preRun': 1711116201613, 'run': 9084}, {'clear': 1, 'end': 1711116210686, 'init': 415, 'preClear': 1711116210685, 'preInit': 1711116201174, 'preRun': 1711116201589, 'run': 9096}]
# Chromium 1255.6000000000931
# Finished chromium test 11466 ms
# Process not running exampleB1
# Running native test
# native run,38
#
# Finished native test 40335 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,6
#
# Finished native-multithread test 8413 ms
# Running test with 12 threads
# Attaching to process 16399
# Attaching to process 16585
# Process not running firefox
# Running firefox test
# Firefox [14, 18, 18, 18, 18, 12, 17, 18, 10, 18, 18, 18]
# 23001
# Firefox [{'clear': 2, 'end': 1711116280402, 'init': 960, 'preClear': 1711116280400, 'preInit': 1711116264661, 'preRun': 1711116265621, 'run': 14779}, {'clear': 2, 'end': 1711116283728, 'init': 872, 'preClear': 1711116283726, 'preInit': 1711116264660, 'preRun': 1711116265532, 'run': 18194}, {'clear': 3, 'end': 1711116283924, 'init': 1018, 'preClear': 1711116283921, 'preInit': 1711116264663, 'preRun': 1711116265681, 'run': 18240}, {'clear': 3, 'end': 1711116283770, 'init': 894, 'preClear': 1711116283767, 'preInit': 1711116264660, 'preRun': 1711116265554, 'run': 18213}, {'clear': 5, 'end': 1711116283706, 'init': 880, 'preClear': 1711116283701, 'preInit': 1711116264660, 'preRun': 1711116265540, 'run': 18161}, {'clear': 4, 'end': 1711116278619, 'init': 963, 'preClear': 1711116278615, 'preInit': 1711116264663, 'preRun': 1711116265626, 'run': 12989}, {'clear': 2, 'end': 1711116282932, 'init': 894, 'preClear': 1711116282930, 'preInit': 1711116264662, 'preRun': 1711116265556, 'run': 17374}, {'clear': 3, 'end': 1711116283793, 'init': 907, 'preClear': 1711116283790, 'preInit': 1711116264661, 'preRun': 1711116265568, 'run': 18222}, {'clear': 9, 'end': 1711116276001, 'init': 939, 'preClear': 1711116275992, 'preInit': 1711116264663, 'preRun': 1711116265602, 'run': 10390}, {'clear': 2, 'end': 1711116283875, 'init': 905, 'preClear': 1711116283873, 'preInit': 1711116264661, 'preRun': 1711116265566, 'run': 18307}, {'clear': 4, 'end': 1711116283770, 'init': 853, 'preClear': 1711116283766, 'preInit': 1711116264661, 'preRun': 1711116265514, 'run': 18252}, {'clear': 3, 'end': 1711116283772, 'init': 1003, 'preClear': 1711116283769, 'preInit': 1711116264662, 'preRun': 1711116265665, 'run': 18104}]
# Firefox 3725
# Finished firefox test 24621 ms
# Process not running chrome
# Running chromium test
# Chromium [8, 8, 8, 7, 8, 8, 8, 8, 7, 7, 8, 7]
# 10402.100000000093
# Chromium [{'clear': 2, 'end': 1711116295318, 'init': 458, 'preClear': 1711116295316, 'preInit': 1711116286614, 'preRun': 1711116287072, 'run': 8244}, {'clear': 2, 'end': 1711116295287, 'init': 412, 'preClear': 1711116295285, 'preInit': 1711116286615, 'preRun': 1711116287027, 'run': 8258}, {'clear': 2, 'end': 1711116295372, 'init': 427, 'preClear': 1711116295370, 'preInit': 1711116286616, 'preRun': 1711116287043, 'run': 8327}, {'clear': 1, 'end': 1711116294854, 'init': 411, 'preClear': 1711116294853, 'preInit': 1711116286614, 'preRun': 1711116287025, 'run': 7828}, {'clear': 1, 'end': 1711116295342, 'init': 353, 'preClear': 1711116295341, 'preInit': 1711116286750, 'preRun': 1711116287103, 'run': 8238}, {'clear': 1, 'end': 1711116295439, 'init': 426, 'preClear': 1711116295438, 'preInit': 1711116286616, 'preRun': 1711116287042, 'run': 8396}, {'clear': 1, 'end': 1711116295383, 'init': 437, 'preClear': 1711116295382, 'preInit': 1711116286615, 'preRun': 1711116287052, 'run': 8330}, {'clear': 1, 'end': 1711116295363, 'init': 362, 'preClear': 1711116295362, 'preInit': 1711116286739, 'preRun': 1711116287101, 'run': 8261}, {'clear': 2, 'end': 1711116294791, 'init': 318, 'preClear': 1711116294789, 'preInit': 1711116286746, 'preRun': 1711116287064, 'run': 7725}, {'clear': 6, 'end': 1711116294742, 'init': 430, 'preClear': 1711116294736, 'preInit': 1711116286617, 'preRun': 1711116287047, 'run': 7689}, {'clear': 1, 'end': 1711116295358, 'init': 423, 'preClear': 1711116295357, 'preInit': 1711116286616, 'preRun': 1711116287039, 'run': 8318}, {'clear': 1, 'end': 1711116294758, 'init': 421, 'preClear': 1711116294757, 'preInit': 1711116286615, 'preRun': 1711116287036, 'run': 7721}]
# Chromium 1569.3999999999069
# Finished chromium test 11185 ms
# Process not running exampleB1
# Running native test
# native run,38
#
# Finished native test 39658 ms
# Process not running exampleB1
# Running native-multithread test
# native-multithread run,6
#
# Finished native-multithread test 8167 ms

# %%
from data_parser import extract_data, extract_time
import pandas as pd

import os

import matplotlib.pyplot as plt



names_browser = ["chromium", "firefox"]
names_native = ["native", "native-multithread"]

folder = "./results/"

sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]

# sort the sub_folders
sub_folders.sort(key=lambda x: int(x.split('_')[1]))
print(sub_folders)


colors = plt.rcParams["axes.prop_cycle"]()

names = names_browser + names_native

def parse_output(folder):
    data_dict= {
        "names": names,
    }

    def plot(names):
        print(f'Plotting {names}')
        max_usages = []
        fig, axs = plt.subplots(len(names), 1,figsize=(5, 8), sharex=True)
        # plot each serie on subplot
        for i,name in enumerate(names):
            print(f'Plotting {name}')
            # extract data from file
            metadata, time_ram_pairs, max_usage = extract_data(folder + name + ".usage.log")
            print(f"Max ram usage for {name}: {max_usage} MiB")
            metadata["name"] = name
            max_usages.append(max_usage)
            c = next(colors)["color"]

            axs[i].plot(
                [pair[0] for pair in time_ram_pairs],
                [pair[1] for pair in time_ram_pairs],
                label=metadata["name"],
                color=c
            )
            axs[i].set_ylabel("ram [MiB]")
            axs[i].set_xlabel("time [s]")
            axs[i].set_title(metadata["name"])
            axs[i].grid(True)


        fig.tight_layout()
        fig.show()
        
        return max_usages


    def plot_ram(names):
        print(f'Plotting ram usage {names}')
        max_usages = plot(names)
        
        plt.figure(figsize=(10, 5))
        plt.bar_label(plt.bar(names, max_usages), labels=[f"{usage:.0f} MiB" for usage in max_usages])
        plt.ylabel("ram [MiB]")
        plt.xlabel("name")
        plt.title("Max ram usage [MiB]")
        plt.show()
        
        return max_usages

    max_ram_usage = plot_ram(names)
    data_dict["max_ram_usage"] = max_ram_usage


    (native_time,_) = extract_time(folder + "native.time.log")
    # ploat all in one plot
    def plot_times(names):
        print(f'Plotting times {names}')
        plt.figure(figsize=(10, 5))
        times = []
        for name in names:
            (time,_) = extract_time(folder + name + ".time.log") 
            
            times.append(time)
            
        plt.bar_label(plt.bar(names, times), labels=[f"{time:.0f}\n({(time/  native_time * 100):.0f}%)" for time in times], padding=-30)
        plt.ylabel("time [s]")
        plt.xlabel("name")
        plt.title("Time of execution")
        plt.show()
        return times
        
    time_duration = plot_times(names)

    data_dict["time_duration"] = time_duration

    df = pd.DataFrame(data_dict)
    
    df.to_csv(folder + "data.csv")
    print("Data saved to data.csv")
    
    return df


frames =[]

for sub_folder in sub_folders:
    print(f'Parsing {sub_folder}')
    df = parse_output(folder + sub_folder + "/")
    print("Parsed")
    df["n_threads"] = int(sub_folder.split('_')[1])
    
    frames.append(df)
    
    
df_concat = pd.concat(frames, axis=0)

plt.figure(figsize=(10, 6))
for name in df_concat['names'].unique():
    df_plot = df_concat[df_concat['names'] == name]
    plt.plot(df_plot['n_threads'], df_plot['time_duration'], label=name)

plt.xlabel('n_threads')
plt.ylabel('time_duration')
plt.title('Time of execution')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
for name in df_concat['names'].unique():
    df_plot = df_concat[df_concat['names'] == name]
    plt.plot(df_plot['n_threads'], df_plot['max_ram_usage'], label=name)

plt.xlabel('n_threads')
plt.ylabel('max_ram_usage')
plt.title('Max ram usage [MiB]')
plt.legend()
plt.show()
# Out:
# ['thread_1', 'thread_2', 'thread_3', 'thread_4', 'thread_6', 'thread_8', 'thread_10', 'thread_12']
# Parsing thread_1
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 680.766 MiB
# Plotting firefox
# Max ram usage for firefox: 1495.453 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed
# Parsing thread_2
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 815.531 MiB
# Plotting firefox
# Max ram usage for firefox: 1721.422 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed
# Parsing thread_3
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 952.078 MiB
# Plotting firefox
# Max ram usage for firefox: 1884.281 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed
# Parsing thread_4
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 1066.219 MiB
# Plotting firefox
# Max ram usage for firefox: 2102.5 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed
# Parsing thread_6
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 1368.172 MiB
# Plotting firefox
# Max ram usage for firefox: 2374.375 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed
# Parsing thread_8
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 1621.938 MiB
# Plotting firefox
# Max ram usage for firefox: 2677.812 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed
# Parsing thread_10
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 1903.359 MiB
# Plotting firefox
# Max ram usage for firefox: 3072.156 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed
# Parsing thread_12
# Plotting ram usage ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting ['chromium', 'firefox', 'native', 'native-multithread']
# Plotting chromium
# Max ram usage for chromium: 2184.422 MiB
# Plotting firefox
# Max ram usage for firefox: 3300.984 MiB
# Plotting native
# Max ram usage for native: 30.445 MiB
# Plotting native-multithread
# Max ram usage for native-multithread: 79.164 MiB
# /var/folders/vx/dqqxq8bs2238z4jxd04dqx400000gn/T/ipykernel_3294/1972064801.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting times ['chromium', 'firefox', 'native', 'native-multithread']
# Data saved to data.csv
# Parsed

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Your data (timestamps and durations in milliseconds)

#firfox python
data = [{'clear': 11, 'end': 1711101888310, 'init': 1299, 'preClear': 1711101888299, 'preInit': 1711101868836, 'preRun': 1711101870135, 'run': 18164}, {'clear': 22, 'end': 1711101885541, 'init': 1817, 'preClear': 1711101885519, 'preInit': 1711101868821, 'preRun': 1711101870638, 'run': 14881}, {'clear': 9, 'end': 1711101891055, 'init': 1405, 'preClear': 1711101891046, 'preInit': 1711101868831, 'preRun': 1711101870236, 'run': 20810}, {'clear': 11, 'end': 1711101890184, 'init': 1738, 'preClear': 1711101890173, 'preInit': 1711101868831, 'preRun': 1711101870569, 'run': 19604}, {'clear': 14, 'end': 1711101886726, 'init': 1731, 'preClear': 1711101886712, 'preInit': 1711101868828, 'preRun': 1711101870559, 'run': 16153}, {'clear': 13, 'end': 1711101887532, 'init': 1655, 'preClear': 1711101887519, 'preInit': 1711101868832, 'preRun': 1711101870487, 'run': 17032}, {'clear': 18, 'end': 1711101883375, 'init': 650, 'preClear': 1711101883357, 'preInit': 1711101868831, 'preRun': 1711101869481, 'run': 13876}, {'clear': 10, 'end': 1711101891920, 'init': 1799, 'preClear': 1711101891910, 'preInit': 1711101868821, 'preRun': 1711101870620, 'run': 21290}]

#firefox manual;
data2 = [{"preInit":1711102203559,"init":541,"preRun":1711102204100,"run":15158,"preClear":1711102219258,"clear":2,"end":1711102219260},{"preInit":1711102203562,"init":554,"preRun":1711102204116,"run":15061,"preClear":1711102219177,"clear":3,"end":1711102219180},{"preInit":1711102203562,"init":534,"preRun":1711102204096,"run":10745,"preClear":1711102214841,"clear":1,"end":1711102214842},{"preInit":1711102203562,"init":528,"preRun":1711102204090,"run":12454,"preClear":1711102216544,"clear":1,"end":1711102216545},{"preInit":1711102203563,"init":524,"preRun":1711102204087,"run":14101,"preClear":1711102218188,"clear":2,"end":1711102218190},{"preInit":1711102203562,"init":541,"preRun":1711102204103,"run":9387,"preClear":1711102213490,"clear":2,"end":1711102213492},{"preInit":1711102203563,"init":515,"preRun":1711102204078,"run":14993,"preClear":1711102219071,"clear":4,"end":1711102219075},{"preInit":1711102203562,"init":535,"preRun":1711102204097,"run":15129,"preClear":1711102219226,"clear":2,"end":1711102219228}]

# chroem manual
data3 = [{"preInit":1711102470495,"init":378,"preRun":1711102470873,"run":8885,"preClear":1711102479758,"clear":2,"end":1711102479760},{"preInit":1711102470496,"init":377,"preRun":1711102470873,"run":8907,"preClear":1711102479780,"clear":1,"end":1711102479781},{"preInit":1711102470496,"init":381,"preRun":1711102470877,"run":8947,"preClear":1711102479824,"clear":1,"end":1711102479825},{"preInit":1711102470496,"init":377,"preRun":1711102470873,"run":8885,"preClear":1711102479758,"clear":1,"end":1711102479759},{"preInit":1711102470495,"init":377,"preRun":1711102470872,"run":8798,"preClear":1711102479670,"clear":4,"end":1711102479674},{"preInit":1711102470496,"init":388,"preRun":1711102470884,"run":8900,"preClear":1711102479784,"clear":1,"end":1711102479785},{"preInit":1711102470496,"init":380,"preRun":1711102470876,"run":8881,"preClear":1711102479757,"clear":2,"end":1711102479759},{"preInit":1711102470496,"init":381,"preRun":1711102470877,"run":8903,"preClear":1711102479780,"clear":1,"end":1711102479781}]

#chrome python
data4= [{'clear': 615, 'end': 1711103093666, 'init': 3563, 'preClear': 1711103093051, 'preInit': 1711103035332, 'preRun': 1711103038895, 'run': 54156}, {'clear': 595, 'end': 1711103093647, 'init': 3563, 'preClear': 1711103093052, 'preInit': 1711103035332, 'preRun': 1711103038895, 'run': 54157}, {'clear': 41, 'end': 1711103093667, 'init': 3563, 'preClear': 1711103093626, 'preInit': 1711103035332, 'preRun': 1711103038895, 'run': 54731}, {'clear': 507, 'end': 1711103093664, 'init': 3564, 'preClear': 1711103093157, 'preInit': 1711103035331, 'preRun': 1711103038895, 'run': 54262}, {'clear': 239, 'end': 1711103093647, 'init': 3563, 'preClear': 1711103093408, 'preInit': 1711103035332, 'preRun': 1711103038895, 'run': 54513}, {'clear': 595, 'end': 1711103093647, 'init': 3563, 'preClear': 1711103093052, 'preInit': 1711103035332, 'preRun': 1711103038895, 'run': 54157}, {'clear': 595, 'end': 1711103093647, 'init': 3563, 'preClear': 1711103093052, 'preInit': 1711103035332, 'preRun': 1711103038895, 'run': 54157}, {'clear': 408, 'end': 1711103093647, 'init': 3563, 'preClear': 1711103093239, 'preInit': 1711103035332, 'preRun': 1711103038895, 'run': 54344}]

def draw_webworker_times(data):
    # Convert timestamps from milliseconds to seconds
    for entry in data:
        for key in entry:
            entry[key] /= 1000

    # Extract timestamps and durations
    timestamps = ['preClear', 'preInit', 'preRun', 'end']

    # Create figure and plot
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.set_title("Timeline of Series Durations")

    # Plot each entry
    markers = ['.', ',', 'o', 'v', '^', '<', '>', '1', '2', '3']
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', '#808080', '#00FF00', '#FF00FF']

    for i,entry in enumerate(data):
        x_values = [entry[stage] for stage in timestamps]
        y_value = i
        
        ax.plot(x_values, [y_value] * len(x_values), "-", label=str(entry))
        
        for i in range(len(x_values)):
            ax.scatter(x_values[i], y_value, marker=markers[i], color=colors[i], s = 50)
            
        
        


    # Annotate lines with series names
    for i, stage in enumerate(timestamps):
        # set on label above the line and one below the line
        
        for j,entry in enumerate(data):
            ax.text(entry[stage], j, stage,  ha="center", va="bottom", rotation=45, fontsize=10)
            
        

    # Remove y-axis and spines
    ax.yaxis.set_visible(False)
    ax.spines[["left", "top", "right"]].set_visible(False)
    ax.margins(y=0.1)

    plt.xlabel("Time")
    # plt.legend()
    plt.show()
    
draw_webworker_times(data)

draw_webworker_times(data2)

draw_webworker_times(data3)


draw_webworker_times(data4)
